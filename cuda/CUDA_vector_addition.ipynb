# %%
# !python --version
# !nvcc --version
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Python 3.10.12
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmprgya6wsc".

# %%
# %%cuda
# #include <stdio.h>
#
#
# struct GpuTimer {
#       cudaEvent_t start;
#       cudaEvent_t stop;
#
#       GpuTimer()
#       {
#             cudaEventCreate(&start);
#             cudaEventCreate(&stop);
#       }
#
#       ~GpuTimer()
#       {
#             cudaEventDestroy(start);
#             cudaEventDestroy(stop);
#       }
#
#       void Start()
#       {
#             cudaEventRecord(start, 0);
#       }
#
#       void Stop()
#       {
#             cudaEventRecord(stop, 0);
#       }
#
#       float Elapsed()
#       {
#             float elapsed;
#             cudaEventSynchronize(stop);
#             cudaEventElapsedTime(&elapsed, start, stop);
#             return elapsed;
#       }
# };
#
#
# void host_add(int *a, int *b, int *c) {
#     for (int idx = 0; idx < N; idx++)
#         c[idx] = a[idx] + b[idx];
# }
#
# __global__ void device_add(int *a, int *b, int *c) {
#     int index = threadIdx.x + blockIdx.x * blockDim.x;
#     if (index < N)
#         c[index] = a[index] + b[index];
# }
#
# void fill_array(int* array, int n) {
#     for (int i = 0; i < n; i++) {
#         array[i] = i; // Example fill operation
#     }
# }
#
# int main(void) {
#     int *a, *b, *c;
#     int *d_a, *d_b, *d_c;
#     int sizes[] = {512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576,
#                2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456};
#     int blocks[] = {16, 32, 64, 128, 256, 512};
#     int no_of_blocks = 0;
#     // GpuTimer timer; // Assuming this is part of some GPU timing library
#     for(int s = 0; s < sizeof(sizes) / sizeof(sizes[0]); s++) {
#         int n = sizes[s];
#         int size = n * sizeof(int);
#
#         a = (int *)malloc(size); fill_array(a, n);
#         b = (int *)malloc(size); fill_array(b, n);
#         c = (int *)malloc(size);
#
#         cudaMalloc((void **)&d_a, size);
#         cudaMalloc((void **)&d_b, size);
#         cudaMalloc((void **)&d_c, size);
#
#         cudaMemcpy(d_a, a, size, cudaMemcpyHostToDevice);
#         cudaMemcpy(d_b, b, size, cudaMemcpyHostToDevice);
#
#         for (int t = 0; t < sizeof(blocks) / sizeof(blocks[0]); t++) {
#             GpuTimer timer;
#
#             int threads_per_block = blocks[t];
#             no_of_blocks = (n + threads_per_block - 1) / threads_per_block;
#
#             timer.Start();
#             device_add<<<no_of_blocks, threads_per_block>>>(d_a, d_b, d_c);
#             cudaDeviceSynchronize();
#             timer.Stop();
#
#             cudaMemcpy(c, d_c, size, cudaMemcpyDeviceToHost);
#
#             printf("N = %d; no_of_blocks = %d; threads_per_block = %d; Elapsed time = %f ms\n", n, no_of_blocks, threads_per_block,timer.Elapsed());
#         }
#
#         free(a); free(b); free(c);
#         cudaFree(d_a); cudaFree(d_b); cudaFree(d_c);
#     }
#
#     return 0;
# }
# Out:
# N = 512; no_of_blocks = 32; threads_per_block = 16; Elapsed time = 0.163904 ms
# N = 512; no_of_blocks = 16; threads_per_block = 32; Elapsed time = 0.015520 ms
# N = 512; no_of_blocks = 8; threads_per_block = 64; Elapsed time = 0.011296 ms
# N = 512; no_of_blocks = 4; threads_per_block = 128; Elapsed time = 0.011808 ms
# N = 512; no_of_blocks = 2; threads_per_block = 256; Elapsed time = 0.011680 ms
# N = 512; no_of_blocks = 1; threads_per_block = 512; Elapsed time = 0.011712 ms
# N = 1024; no_of_blocks = 64; threads_per_block = 16; Elapsed time = 0.014336 ms
# N = 1024; no_of_blocks = 32; threads_per_block = 32; Elapsed time = 0.012416 ms
# N = 1024; no_of_blocks = 16; threads_per_block = 64; Elapsed time = 0.011168 ms
# N = 1024; no_of_blocks = 8; threads_per_block = 128; Elapsed time = 0.011360 ms
# N = 1024; no_of_blocks = 4; threads_per_block = 256; Elapsed time = 0.011776 ms
# N = 1024; no_of_blocks = 2; threads_per_block = 512; Elapsed time = 0.011680 ms
# N = 2048; no_of_blocks = 128; threads_per_block = 16; Elapsed time = 0.012480 ms
# N = 2048; no_of_blocks = 64; threads_per_block = 32; Elapsed time = 0.012352 ms
# N = 2048; no_of_blocks = 32; threads_per_block = 64; Elapsed time = 0.012608 ms
# N = 2048; no_of_blocks = 16; threads_per_block = 128; Elapsed time = 0.011776 ms
# N = 2048; no_of_blocks = 8; threads_per_block = 256; Elapsed time = 0.011232 ms
# N = 2048; no_of_blocks = 4; threads_per_block = 512; Elapsed time = 0.011584 ms
# N = 4096; no_of_blocks = 256; threads_per_block = 16; Elapsed time = 0.012288 ms
# N = 4096; no_of_blocks = 128; threads_per_block = 32; Elapsed time = 0.013152 ms
# N = 4096; no_of_blocks = 64; threads_per_block = 64; Elapsed time = 0.012000 ms
# N = 4096; no_of_blocks = 32; threads_per_block = 128; Elapsed time = 0.011680 ms
# N = 4096; no_of_blocks = 16; threads_per_block = 256; Elapsed time = 0.011488 ms
# N = 4096; no_of_blocks = 8; threads_per_block = 512; Elapsed time = 0.012224 ms
# N = 8192; no_of_blocks = 512; threads_per_block = 16; Elapsed time = 0.010336 ms
# N = 8192; no_of_blocks = 256; threads_per_block = 32; Elapsed time = 0.011648 ms
# N = 8192; no_of_blocks = 128; threads_per_block = 64; Elapsed time = 0.011840 ms
# N = 8192; no_of_blocks = 64; threads_per_block = 128; Elapsed time = 0.011712 ms
# N = 8192; no_of_blocks = 32; threads_per_block = 256; Elapsed time = 0.011392 ms
# N = 8192; no_of_blocks = 16; threads_per_block = 512; Elapsed time = 0.011584 ms
# N = 16384; no_of_blocks = 1024; threads_per_block = 16; Elapsed time = 0.013888 ms
# N = 16384; no_of_blocks = 512; threads_per_block = 32; Elapsed time = 0.012704 ms
# N = 16384; no_of_blocks = 256; threads_per_block = 64; Elapsed time = 0.013984 ms
# N = 16384; no_of_blocks = 128; threads_per_block = 128; Elapsed time = 0.012000 ms
# N = 16384; no_of_blocks = 64; threads_per_block = 256; Elapsed time = 0.011392 ms
# N = 16384; no_of_blocks = 32; threads_per_block = 512; Elapsed time = 0.011744 ms
# N = 32768; no_of_blocks = 2048; threads_per_block = 16; Elapsed time = 0.017792 ms
# N = 32768; no_of_blocks = 1024; threads_per_block = 32; Elapsed time = 0.015008 ms
# N = 32768; no_of_blocks = 512; threads_per_block = 64; Elapsed time = 0.012256 ms
# N = 32768; no_of_blocks = 256; threads_per_block = 128; Elapsed time = 0.020736 ms
# N = 32768; no_of_blocks = 128; threads_per_block = 256; Elapsed time = 0.012192 ms
# N = 32768; no_of_blocks = 64; threads_per_block = 512; Elapsed time = 0.011104 ms
# N = 65536; no_of_blocks = 4096; threads_per_block = 16; Elapsed time = 0.030336 ms
# N = 65536; no_of_blocks = 2048; threads_per_block = 32; Elapsed time = 0.019072 ms
# N = 65536; no_of_blocks = 1024; threads_per_block = 64; Elapsed time = 0.016352 ms
# N = 65536; no_of_blocks = 512; threads_per_block = 128; Elapsed time = 0.013152 ms
# N = 65536; no_of_blocks = 256; threads_per_block = 256; Elapsed time = 0.012832 ms
# N = 65536; no_of_blocks = 128; threads_per_block = 512; Elapsed time = 0.018048 ms
# N = 131072; no_of_blocks = 8192; threads_per_block = 16; Elapsed time = 0.037664 ms
# N = 131072; no_of_blocks = 4096; threads_per_block = 32; Elapsed time = 0.026048 ms
# N = 131072; no_of_blocks = 2048; threads_per_block = 64; Elapsed time = 0.017856 ms
# N = 131072; no_of_blocks = 1024; threads_per_block = 128; Elapsed time = 0.020288 ms
# N = 131072; no_of_blocks = 512; threads_per_block = 256; Elapsed time = 0.016416 ms
# N = 131072; no_of_blocks = 256; threads_per_block = 512; Elapsed time = 0.015872 ms
# N = 262144; no_of_blocks = 16384; threads_per_block = 16; Elapsed time = 0.060992 ms
# N = 262144; no_of_blocks = 8192; threads_per_block = 32; Elapsed time = 0.037856 ms
# N = 262144; no_of_blocks = 4096; threads_per_block = 64; Elapsed time = 0.023328 ms
# N = 262144; no_of_blocks = 2048; threads_per_block = 128; Elapsed time = 0.018720 ms
# N = 262144; no_of_blocks = 1024; threads_per_block = 256; Elapsed time = 0.023488 ms
# N = 262144; no_of_blocks = 512; threads_per_block = 512; Elapsed time = 0.022368 ms
# N = 524288; no_of_blocks = 32768; threads_per_block = 16; Elapsed time = 0.116608 ms
# N = 524288; no_of_blocks = 16384; threads_per_block = 32; Elapsed time = 0.069152 ms
# N = 524288; no_of_blocks = 8192; threads_per_block = 64; Elapsed time = 0.038112 ms
# N = 524288; no_of_blocks = 4096; threads_per_block = 128; Elapsed time = 0.034560 ms
# N = 524288; no_of_blocks = 2048; threads_per_block = 256; Elapsed time = 0.036128 ms
# N = 524288; no_of_blocks = 1024; threads_per_block = 512; Elapsed time = 0.036832 ms
# N = 1048576; no_of_blocks = 65536; threads_per_block = 16; Elapsed time = 0.214528 ms
# N = 1048576; no_of_blocks = 32768; threads_per_block = 32; Elapsed time = 0.120032 ms
# N = 1048576; no_of_blocks = 16384; threads_per_block = 64; Elapsed time = 0.061152 ms
# N = 1048576; no_of_blocks = 8192; threads_per_block = 128; Elapsed time = 0.056608 ms
# N = 1048576; no_of_blocks = 4096; threads_per_block = 256; Elapsed time = 0.057984 ms
# N = 1048576; no_of_blocks = 2048; threads_per_block = 512; Elapsed time = 0.058496 ms
# N = 2097152; no_of_blocks = 131072; threads_per_block = 16; Elapsed time = 0.396576 ms
# N = 2097152; no_of_blocks = 65536; threads_per_block = 32; Elapsed time = 0.211328 ms
# N = 2097152; no_of_blocks = 32768; threads_per_block = 64; Elapsed time = 0.100448 ms
# N = 2097152; no_of_blocks = 16384; threads_per_block = 128; Elapsed time = 0.071424 ms
# N = 2097152; no_of_blocks = 8192; threads_per_block = 256; Elapsed time = 0.069024 ms
# N = 2097152; no_of_blocks = 4096; threads_per_block = 512; Elapsed time = 0.071232 ms
# N = 4194304; no_of_blocks = 262144; threads_per_block = 16; Elapsed time = 0.762720 ms
# N = 4194304; no_of_blocks = 131072; threads_per_block = 32; Elapsed time = 0.396896 ms
# N = 4194304; no_of_blocks = 65536; threads_per_block = 64; Elapsed time = 0.183904 ms
# N = 4194304; no_of_blocks = 32768; threads_per_block = 128; Elapsed time = 0.103936 ms
# N = 4194304; no_of_blocks = 16384; threads_per_block = 256; Elapsed time = 0.094240 ms
# N = 4194304; no_of_blocks = 8192; threads_per_block = 512; Elapsed time = 0.094144 ms
# N = 8388608; no_of_blocks = 524288; threads_per_block = 16; Elapsed time = 1.485024 ms
# N = 8388608; no_of_blocks = 262144; threads_per_block = 32; Elapsed time = 0.767040 ms
# N = 8388608; no_of_blocks = 131072; threads_per_block = 64; Elapsed time = 0.337760 ms
# N = 8388608; no_of_blocks = 65536; threads_per_block = 128; Elapsed time = 0.163712 ms
# N = 8388608; no_of_blocks = 32768; threads_per_block = 256; Elapsed time = 0.140096 ms
# N = 8388608; no_of_blocks = 16384; threads_per_block = 512; Elapsed time = 0.149088 ms
# N = 16777216; no_of_blocks = 1048576; threads_per_block = 16; Elapsed time = 2.933216 ms
# N = 16777216; no_of_blocks = 524288; threads_per_block = 32; Elapsed time = 1.492256 ms
# N = 16777216; no_of_blocks = 262144; threads_per_block = 64; Elapsed time = 0.651936 ms
# N = 16777216; no_of_blocks = 131072; threads_per_block = 128; Elapsed time = 0.288608 ms
# N = 16777216; no_of_blocks = 65536; threads_per_block = 256; Elapsed time = 0.232000 ms
# N = 16777216; no_of_blocks = 32768; threads_per_block = 512; Elapsed time = 0.240800 ms
# N = 33554432; no_of_blocks = 2097152; threads_per_block = 16; Elapsed time = 5.821056 ms
# N = 33554432; no_of_blocks = 1048576; threads_per_block = 32; Elapsed time = 2.956000 ms
# N = 33554432; no_of_blocks = 524288; threads_per_block = 64; Elapsed time = 1.270336 ms
# N = 33554432; no_of_blocks = 262144; threads_per_block = 128; Elapsed time = 0.533632 ms
# N = 33554432; no_of_blocks = 131072; threads_per_block = 256; Elapsed time = 0.415072 ms
# N = 33554432; no_of_blocks = 65536; threads_per_block = 512; Elapsed time = 0.433216 ms
# N = 67108864; no_of_blocks = 4194304; threads_per_block = 16; Elapsed time = 11.615872 ms
# N = 67108864; no_of_blocks = 2097152; threads_per_block = 32; Elapsed time = 5.867424 ms
# N = 67108864; no_of_blocks = 1048576; threads_per_block = 64; Elapsed time = 2.527840 ms
# N = 67108864; no_of_blocks = 524288; threads_per_block = 128; Elapsed time = 1.014848 ms
# N = 67108864; no_of_blocks = 262144; threads_per_block = 256; Elapsed time = 0.731872 ms
# N = 67108864; no_of_blocks = 131072; threads_per_block = 512; Elapsed time = 0.756224 ms
# N = 134217728; no_of_blocks = 8388608; threads_per_block = 16; Elapsed time = 18.974655 ms
# N = 134217728; no_of_blocks = 4194304; threads_per_block = 32; Elapsed time = 9.490720 ms
# N = 134217728; no_of_blocks = 2097152; threads_per_block = 64; Elapsed time = 4.103200 ms
# N = 134217728; no_of_blocks = 1048576; threads_per_block = 128; Elapsed time = 1.243232 ms
# N = 134217728; no_of_blocks = 524288; threads_per_block = 256; Elapsed time = 1.048416 ms
# N = 134217728; no_of_blocks = 262144; threads_per_block = 512; Elapsed time = 0.799008 ms
# N = 268435456; no_of_blocks = 16777216; threads_per_block = 16; Elapsed time = 46.521183 ms
# N = 268435456; no_of_blocks = 8388608; threads_per_block = 32; Elapsed time = 18.263391 ms
# N = 268435456; no_of_blocks = 4194304; threads_per_block = 64; Elapsed time = 7.871136 ms
# N = 268435456; no_of_blocks = 2097152; threads_per_block = 128; Elapsed time = 2.031840 ms
# N = 268435456; no_of_blocks = 1048576; threads_per_block = 256; Elapsed time = 1.342464 ms
# N = 268435456; no_of_blocks = 524288; threads_per_block = 512; Elapsed time = 1.357888 ms
